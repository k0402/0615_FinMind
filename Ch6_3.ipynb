# %% [markdown]
# <a href="https://colab.research.google.com/github/k0402/0615_FinMind/blob/main/Ch6_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
程式碼儲存格 <R208LMYdxAYg>
# %% [code]
#爬蟲
#1. 即時YouBike空位查詢
import requests
import json
url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
web = requests.get(url, verify=False)
web.encoding='utf-8'
list_of_dicts = web.json()
myarea = "文山區"
for i in list_of_dicts:
 if i["sarea"] == myarea:
  print(i["sno"], i["sna"], "總數:" + str(i["tot"]), "剩餘:" +str(i["sbi"]), i["infoTime"], i["ar"])
執行輸出開始時間：2023年4月21日 下午4:04
7KB
	Stream
		/usr/local/lib/python3.9/dist-packages/urllib3/connectionpool.py:1045: InsecureRequestWarning: Unverified HTTPS request is being made to host 'tcgbusfs.blob.core.windows.net'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/1.26.x/advanced-usage.html#ssl-warnings
		  warnings.warn(
		500105001 YouBike2.0_台北花木批發市場 總數:32 剩餘:5 2023-04-21 15:58:14 萬盛街/興隆路一段(西北側)
		500105002 YouBike2.0_捷運萬隆站(4號出口) 總數:21 剩餘:5 2023-04-21 15:55:22 羅斯福路5段210號(前)
		500105003 YouBike2.0_捷運萬隆站(1號出口) 總數:34 剩餘:3 2023-04-21 16:01:16 羅斯福路五段250號(前)
		500105004 YouBike2.0_萬和二號公園 總數:26 剩餘:6 2023-04-21 15:36:14 萬隆街255號(對面)
		500105005 YouBike2.0_捷運萬隆站(2號出口) 總數:12 剩餘:1 2023-04-21 16:03:04 興隆路一段70巷/羅斯福路5段211巷26弄口
		500105006 YouBike2.0_景仁公園 總數:16 剩餘:8 2023-04-21 16:03:04 羅斯福路六段142巷1號(旁)
		500105007 YouBike2.0_捷運景美站(2號出口) 總數:63 剩餘:9 2023-04-21 15:57:14 景文街1號(對面)
		500105008 YouBike2.0_羅斯福景隆街口 總數:20 剩餘:3 2023-04-21 15:58:14 羅斯福路六段/景隆街口(東南側)
		500105009 YouBike2.0_景福街/羅斯福路6段142巷口 總數:28 剩餘:6 2023-04-21 15:58:14 景福街/羅斯福路6段142巷口
		500105010 YouBike2.0_興旺公園 總數:30 剩餘:0 2023-04-21 14:11:04 福興路106巷28弄96號(對面)
		500105011 YouBike2.0_興福國中 總數:25 剩餘:1 2023-04-21 16:03:04 福興路95巷/福興路63巷4弄口
		500105012 YouBike2.0_興隆路2段203巷 總數:32 剩餘:2 2023-04-21 15:58:04 興隆路2段203巷108號(對面)
		500105013 YouBike2.0_景美運動公園 總數:11 剩餘:2 2023-04-21 15:44:14 景豐街79號(旁公園)
		500105014 YouBike2.0_景美醫院 總數:18 剩餘:4 2023-04-21 15:59:14 羅斯福路六段280號(前)
		500105015 YouBike2.0_師範大學公館校區 總數:14 剩餘:8 2023-04-21 16:02:19 汀州路四段77號(旁)
		500105016 YouBike2.0_景華街128巷口 總數:20 剩餘:4 2023-04-21 16:03:04 景華街124號(旁汽車格)
		500105017 YouBike2.0_仙跡岩登山口(景興路) 總數:22 剩餘:7 2023-04-21 15:43:15 景興街239號(前)
		500105018 YouBike2.0_國立政治大學 總數:35 剩餘:13 2023-04-21 16:01:16 指南路二段153號(對面)
		500105066 YouBike2.0_景美污水抽水站 總數:15 剩餘:1 2023-04-21 16:01:16 汀州路四段10號北側人行道
		500105067 YouBike2.0_萬和三號公園(北側) 總數:13 剩餘:7 2023-04-21 15:58:14 溪洲街107巷(公園北側)
		500105068 YouBike2.0_景興國中 總數:10 剩餘:0 2023-04-21 12:59:04 三福街4巷與景興路46巷口
		500105069 YouBike2.0_景仁公園_1 總數:15 剩餘:2 2023-04-21 16:03:04 景仁街 / 羅斯福路六段142巷口(北側)
		500105070 YouBike2.0_師大公館校區學二舍 總數:40 剩餘:10 2023-04-21 16:03:04 臺灣師範大學學二舍西側人行道
		500105071 YouBike2.0_景行公園 總數:15 剩餘:1 2023-04-21 15:59:04 景中街與景中街30巷口
		500105072 YouBike2.0_萬興國小 總數:16 剩餘:10 2023-04-21 15:35:14 秀明路二段114號公車亭旁
		500105073 YouBike2.0_辛亥路四段77巷口 總數:14 剩餘:1 2023-04-21 15:22:04 辛亥路四段77巷口
		500105074 YouBike2.0_景興路42巷口 總數:12 剩餘:6 2023-04-21 16:01:16 景興路42巷與景興路口西南側
		500105075 YouBike2.0_木柵路三段48巷 總數:15 剩餘:0 2023-04-21 13:37:04 木柵路三段48巷1弄口
		500105076 YouBike2.0_木柵路二段109巷 總數:15 剩餘:8 2023-04-21 16:02:19 木柵路二段109巷14號旁
		500105077 YouBike2.0_試院公園 總數:15 剩餘:2 2023-04-21 16:03:04 木柵路一段59巷29號對側
		500105080 YouBike2.0_萬美萬安街口 總數:16 剩餘:10 2023-04-21 12:25:15 萬美街一段/萬安街口
		500105081 YouBike2.0_興隆路二段203巷(敦南) 總數:27 剩餘:1 2023-04-21 15:48:04 興隆路二段203巷16號
		500105082 YouBike2.0_新光秀明路口 總數:15 剩餘:5 2023-04-21 15:51:14 新光路一段145號前

程式碼儲存格 <D28RreG8sDMA>
# %% [code]
#2. 統一發票查詢
import requests
url = 'https://invoice.etax.nat.gov.tw/index.html'
web = requests.get(url)
web.encoding='utf-8'
from bs4 import BeautifulSoup
#轉換成標籤樹
soup = BeautifulSoup(web.text, "html.parser")
#取出中獎號碼的位置
tt= soup.find(class_='etw-container').find(class_='etw-on').text
td = soup.find_all(class_='etw-tbiggest')
ns = td[0].getText()  #特別獎
n1 = td[1].getText()  #特獎
# 頭獎，出現/n換行符，使用[-8:]取出最後八碼
n2 = [td[2].getText()[-8:], td[3].getText()[-8:], td[4].getText()[-8:]]
print(tt)
print("特別獎: " + (ns))
print("特獎: " + (n1))
print("頭獎: " + n2[0] + "," + n2[1] + "," + n2[2])
執行輸出開始時間：2023年4月21日 下午4:04
0KB
	Stream
		112年01-02月中獎號碼單
		特別獎: 06634385
		特獎: 66882140
		頭獎: 25722152,93412693,16957025
# Out:
#   File "<ipython-input-2-73bbe9657aea>", line 15
#     執行輸出開始時間：2023年4月21日 下午4:04
#             ^
# SyntaxError: invalid character '：' (U+FF1A)
